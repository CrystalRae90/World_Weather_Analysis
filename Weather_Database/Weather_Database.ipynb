# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs =zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
          cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 774

# %%
cities
# Out:
# ['malibu',
#  'gazojak',
#  'necochea',
#  'hami',
#  'port elizabeth',
#  'vestmannaeyjar',
#  'tuban',
#  'ushuaia',
#  'hermanus',
#  'umzimvubu',
#  'la ronge',
#  'acuna',
#  'sambava',
#  'varkaus',
#  'paradwip',
#  'ilulissat',
#  'srednekolymsk',
#  'atuona',
#  'bluff',
#  'rikitea',
#  'sorvag',
#  'los llanos de aridane',
#  'port alfred',
#  'taolanaro',
#  'seddon',
#  'hithadhoo',
#  'kapaa',
#  'fontenay-le-comte',
#  'saskylakh',
#  'punta arenas',
#  'tura',
#  'nizhneyansk',
#  'mataura',
#  'kholm-zhirkovskiy',
#  'havoysund',
#  'salalah',
#  'takoradi',
#  'puerto ayora',
#  'georgetown',
#  'lavrentiya',
#  'kendari',
#  'andselv',
#  'klaksvik',
#  'oranjemund',
#  'myrtle beach',
#  'tumannyy',
#  'soyo',
#  'port keats',
#  'ribeira grande',
#  'shiraoi',
#  'jalor',
#  'albany',
#  'dudinka',
#  'rabo de peixe',
#  'ust-tsilma',
#  'dingle',
#  'pringsewu',
#  'waipawa',
#  'kamenskoye',
#  'igarka',
#  'qaanaaq',
#  'kibaya',
#  'bengkulu',
#  'guerrero negro',
#  'amderma',
#  'new norfolk',
#  'hobart',
#  'chokurdakh',
#  'hilo',
#  'bairiki',
#  'san carlos de bariloche',
#  'hambantota',
#  'provideniya',
#  'jamestown',
#  'khatanga',
#  'barrow',
#  'yuzhno-yeniseyskiy',
#  'codajas',
#  'margate',
#  'zapadnaya dvina',
#  'soldatskaya',
#  'attawapiskat',
#  'barentsburg',
#  'camopi',
#  'cordenons',
#  'garowe',
#  'bahua',
#  'ryotsu',
#  'sao paulo de olivenca',
#  'nikolskoye',
#  'avarua',
#  'bethanien',
#  'vaini',
#  'coquimbo',
#  'sentyabrskiy',
#  'castro',
#  'mehamn',
#  'lorengau',
#  'yarim',
#  'ponta do sol',
#  'oxford',
#  'mar del plata',
#  'busselton',
#  'san isidro',
#  'tuktoyaktuk',
#  'souillac',
#  'aflu',
#  'poddorye',
#  'prince albert',
#  'nemuro',
#  'benguela',
#  'borama',
#  'fort nelson',
#  'faanui',
#  'kodiak',
#  'namatanai',
#  'kaitangata',
#  'loreto',
#  'illoqqortoormiut',
#  'beira',
#  'yeppoon',
#  'bethel',
#  'martinsville',
#  'aswan',
#  'cape town',
#  'kenai',
#  'cherskiy',
#  'arman',
#  'torbay',
#  'ishikawa',
#  'makasar',
#  'saleaula',
#  'stephenville',
#  'isangel',
#  'resistencia',
#  'funadhoo',
#  'victoria',
#  'preobrazheniye',
#  'halalo',
#  'okhotsk',
#  'qui nhon',
#  'campos novos',
#  'east london',
#  'grand centre',
#  'abu samrah',
#  'belushya guba',
#  'san patricio',
#  'shumikha',
#  'chuy',
#  'cidreira',
#  'saint-philippe',
#  'kukuna',
#  'tiksi',
#  'marystown',
#  'rodrigues alves',
#  'beringovskiy',
#  'biak',
#  'bara',
#  'upernavik',
#  'mahebourg',
#  'vila velha',
#  'tigil',
#  'walvis bay',
#  'yellowknife',
#  'vila franca do campo',
#  'crossville',
#  'kahului',
#  'lodwar',
#  'kamenka',
#  'carnarvon',
#  'butaritari',
#  'moose factory',
#  'bereda',
#  'salou',
#  'umm kaddadah',
#  'bambous virieux',
#  'qaqortoq',
#  'changping',
#  'tasiilaq',
#  'hervey bay',
#  'ylojarvi',
#  'lebu',
#  'nowy dwor gdanski',
#  'kurayoshi',
#  'severo-kurilsk',
#  'riohacha',
#  'messina',
#  'lata',
#  'sitka',
#  'thompson',
#  'shatin',
#  'esperance',
#  'nanortalik',
#  'fenoarivo atsinanana',
#  'pechenga',
#  'tarifa',
#  'nampula',
#  'arraial do cabo',
#  'salta',
#  'saint-louis',
#  'huarmey',
#  'berdigestyakh',
#  'ust-kuyga',
#  'palmas bellas',
#  'kerouane',
#  'paengaroa',
#  'djambala',
#  'mhango',
#  'lagoa',
#  'laguna',
#  'tabiauea',
#  'celestun',
#  'ler',
#  'katsuura',
#  'bur gabo',
#  'kruisfontein',
#  'samusu',
#  'belogorsk',
#  'sungaipenuh',
#  'george town',
#  'ixtapa',
#  'tuy hoa',
#  'vadso',
#  'eureka',
#  'komsomolskiy',
#  'yebaishou',
#  'mys shmidta',
#  'ratnagiri',
#  'shagonar',
#  'maceio',
#  'codrington',
#  'grand river south east',
#  'whitehorse',
#  'birao',
#  'luanda',
#  'tambo grande',
#  'hamilton',
#  'karratha',
#  'clyde river',
#  'tsihombe',
#  'shipley',
#  'parrita',
#  'russell',
#  'kuching',
#  'mackay',
#  'taos',
#  'vardo',
#  'samarai',
#  'bambanglipuro',
#  'puerto escondido',
#  'hun',
#  'evanston',
#  'vaitupu',
#  'caravelas',
#  'mayo',
#  'huilong',
#  'iqaluit',
#  'kaeo',
#  'anloga',
#  'sinnai',
#  'puerto carreno',
#  'pevek',
#  'saldanha',
#  'luau',
#  'bullhead city',
#  'beidao',
#  'hassleholm',
#  'syracuse',
#  'mackenzie',
#  'talnakh',
#  'port macquarie',
#  'port hardy',
#  'luderitz',
#  'penarroya-pueblonuevo',
#  'okahandja',
#  'balikpapan',
#  'dwarka',
#  'narsaq',
#  'bloomingdale',
#  'razdolinsk',
#  'denpasar',
#  'chester',
#  'davila',
#  'gondar',
#  'charters towers',
#  'ulladulla',
#  'bathsheba',
#  'lagos',
#  'ulaangom',
#  'naze',
#  'mbandaka',
#  'tomatlan',
#  'geraldton',
#  'pemba',
#  'ballina',
#  'lasa',
#  'bredasdorp',
#  'blind river',
#  'kavieng',
#  'lompoc',
#  'miri',
#  'bonthe',
#  'champerico',
#  'belmopan',
#  'marzuq',
#  'jackson',
#  'tessalit',
#  'pangnirtung',
#  'texas city',
#  'burica',
#  'padang',
#  'portland',
#  'acapulco',
#  'brae',
#  'mandera',
#  'killybegs',
#  'auki',
#  'verkh-suetka',
#  'mandalgovi',
#  'damietta',
#  'saint george',
#  'mandan',
#  'tyrma',
#  'rio gallegos',
#  'mingshui',
#  'korostyshiv',
#  'warri',
#  'port blair',
#  'asau',
#  'hadejia',
#  'springbok',
#  'uyemskiy',
#  'tokur',
#  'saint anthony',
#  'kempsey',
#  'baracoa',
#  'general pico',
#  'mergui',
#  'lerwick',
#  'lac du bonnet',
#  'charyshskoye',
#  'bloomington',
#  'mapiripan',
#  'sao felix do xingu',
#  'zambezi',
#  'muskegon',
#  'oistins',
#  'nioro',
#  'afanasyevo',
#  'norman wells',
#  'rocha',
#  'yongan',
#  'cambridge',
#  'qixia',
#  'harper',
#  'bilma',
#  'altay',
#  'zempoala',
#  'petropavlovsk-kamchatskiy',
#  'batemans bay',
#  'louisbourg',
#  'cayenne',
#  'vokhma',
#  'elverum',
#  'sorong',
#  'touros',
#  'gbarnga',
#  'francisco sa',
#  'dunedin',
#  'nyimba',
#  'benjamin aceval',
#  'bari',
#  'mogadishu',
#  'zhigansk',
#  'jalu',
#  'marsh harbour',
#  'taoudenni',
#  'coihaique',
#  'talcahuano',
#  'kismayo',
#  'mokhsogollokh',
#  'cuxhaven',
#  'kirakira',
#  'burla',
#  'cap-aux-meules',
#  'te anau',
#  'zaozerne',
#  'marsa matruh',
#  'ialibu',
#  'vondrozo',
#  'saurimo',
#  'nelson bay',
#  'ambagarh chauki',
#  'katobu',
#  'indian head',
#  'ahipara',
#  'eregli',
#  'sindor',
#  'zhengjiatun',
#  'maloy',
#  'thinadhoo',
#  'male',
#  'saint-pierre',
#  'kuusamo',
#  'moshny',
#  'port hedland',
#  'ancud',
#  'villa carlos paz',
#  'santa isabel do rio negro',
#  'novo aripuana',
#  'the valley',
#  'gat',
#  'bandarbeyla',
#  'kudahuvadhoo',
#  'sabang',
#  'semme',
#  'troitsko-pechorsk',
#  'tanout',
#  'tamiahua',
#  'dolbeau',
#  'tibu',
#  'fare',
#  'lagunas',
#  'utiroa',
#  'tarauaca',
#  'mount isa',
#  'puerto baquerizo moreno',
#  'khasan',
#  'belize',
#  'bolungarvik',
#  'longyearbyen',
#  'teya',
#  'sovetskaya gavan',
#  'poum',
#  'san jose',
#  'lucapa',
#  'sao joao da barra',
#  'susanville',
#  'havelock',
#  'belyy yar',
#  'yulara',
#  'powell river',
#  'baherden',
#  'grindavik',
#  'binga',
#  'alenquer',
#  'yantal',
#  'anadyr',
#  'araouane',
#  'oriximina',
#  'bubaque',
#  'larsnes',
#  'montepuez',
#  'bafoulabe',
#  'lugovoy',
#  'gurskoye',
#  'deder',
#  'ginebra',
#  'pemangkat',
#  'bayangol',
#  'praya',
#  'tunxi',
#  'nikki',
#  'ambunti',
#  'port lincoln',
#  'aklavik',
#  'saint-joseph',
#  'seaforth',
#  'pinega',
#  'paamiut',
#  'andenes',
#  'aosta',
#  'stokmarknes',
#  'ouahigouya',
#  'gabi',
#  'kristiinankaupunki',
#  'havre-saint-pierre',
#  'ugoofaaru',
#  'moshi',
#  'praia da vitoria',
#  'nynashamn',
#  'leningradskiy',
#  'sinnamary',
#  'tambun',
#  'udachnyy',
#  'povolzhskiy',
#  'henties bay',
#  'behshahr',
#  'de-kastri',
#  'gizo',
#  'half moon bay',
#  'broken hill',
#  'riacho de santana',
#  'verkhoyansk',
#  'grand gaube',
#  'panzhihua',
#  'baie-comeau',
#  'lewisporte',
#  'meridian',
#  'avera',
#  'dikson',
#  'pacific grove',
#  'trinec',
#  'fallon',
#  'inta',
#  'cockburn town',
#  'waitati',
#  'el alto',
#  'scalea',
#  'waterloo',
#  'brive-la-gaillarde',
#  'nuevo progreso',
#  'ranau',
#  'constitucion',
#  'sao filipe',
#  'muros',
#  'buala',
#  'inirida',
#  'pasighat',
#  'nishihara',
#  'nantucket',
#  'clonakilty',
#  'kuito',
#  'san andres',
#  'sakakah',
#  'el cobre',
#  'kuressaare',
#  'caluquembe',
#  'altar',
#  'pangai',
#  'tapaua',
#  'belmonte',
#  'moron',
#  'korgen',
#  'toftir',
#  'carutapera',
#  'montrose',
#  'quimper',
#  'xichang',
#  'sinazongwe',
#  'fort saint john',
#  'kodinsk',
#  'aksarka',
#  'skalistyy',
#  'ucluelet',
#  'san jose de tarros',
#  'high level',
#  'haines junction',
#  'bo phloi',
#  'mabaruma',
#  'kresttsy',
#  'lundazi',
#  'mizdah',
#  'beinamar',
#  'salinopolis',
#  'namibe',
#  'faya',
#  'eyl',
#  'castanos',
#  'oliver',
#  'san policarpo',
#  'san jeronimo',
#  'tequila',
#  'ranong',
#  'fortuna',
#  'eenhana',
#  'birjand',
#  'vila',
#  'ust-maya',
#  'westpunt',
#  'nizhneivkino',
#  'talas',
#  'darnah',
#  'alta floresta',
#  'dalianwan',
#  'macaboboni',
#  'tuatapere',
#  'hirado',
#  'sola',
#  'tayshet',
#  'zemio',
#  'banugao',
#  'verkhnevilyuysk',
#  'buraydah',
#  'soubre',
#  'mangochi',
#  'bud',
#  'deer lake',
#  'avdiyivka',
#  'kamyshin',
#  'ayr',
#  'opuwo',
#  'kytlym',
#  'airai',
#  'gaffney',
#  'wulanhaote',
#  'comodoro rivadavia',
#  'wakkanai',
#  'goundam',
#  'arlit',
#  'estelle',
#  'katherine',
#  'iowa city',
#  'la palma',
#  'hasaki',
#  'khani',
#  'waingapu',
#  'malitbog',
#  'akcakoca',
#  'northam',
#  'husavik',
#  'cessnock',
#  'bogatic',
#  'mouzakion',
#  'usinsk',
#  'turukhansk',
#  'cloquet',
#  'port-gentil',
#  'dunkirk',
#  'prado',
#  'vostok',
#  'siavonga',
#  'maridi',
#  'babu',
#  'wanning',
#  'contai',
#  'sioux lookout',
#  'nome',
#  'teknaf',
#  'sept-iles',
#  'dubbo',
#  'andevoranto',
#  'mount pleasant',
#  'gravdal',
#  'batalha',
#  'millinocket',
#  'hokitika',
#  'jaicos',
#  'amahai',
#  'isla aguada',
#  'vung tau',
#  'maracas',
#  'lensk',
#  'ketchikan',
#  'praia',
#  'honiara',
#  'tabuk',
#  'gorkovskoye',
#  'barbar',
#  'mangrol',
#  'ndjole',
#  'balkhash',
#  'kutum',
#  'dingli',
#  'solnechnyy',
#  'vestmanna',
#  'hearst',
#  'kachug',
#  'sohagpur',
#  'chernyshevskiy',
#  'byron bay',
#  'omurtag',
#  'nara',
#  'qasigiannguit',
#  'jieshi',
#  'ostrovnoy',
#  'chicama',
#  'longview',
#  'aras',
#  'zhanatas',
#  'ashland',
#  'bowmore',
#  'santa vitoria do palmar',
#  'boguchany',
#  'rosehearty',
#  'kupang',
#  'san quintin',
#  'cabo san lucas',
#  'kulhudhuffushi',
#  'assiniboia',
#  'belur',
#  'kisangani',
#  'nizhniy odes',
#  'waw',
#  'leiva',
#  'nizwa',
#  'sarkand',
#  'filingue',
#  'san cristobal',
#  'bemidji',
#  'osmena',
#  'labuhan',
#  'saint-francois',
#  'alice springs',
#  'matara',
#  'koundara',
#  'olafsvik',
#  'marcona',
#  'tulum',
#  'sahuaripa',
#  'mount gambier',
#  'mkushi',
#  'george',
#  'kijang',
#  'pechora',
#  'bilibino',
#  'dryden',
#  'puerto madryn',
#  'panaba',
#  'tawnat',
#  'tabursuq',
#  'bhatgaon',
#  'naliya',
#  'artsyz',
#  'magalia',
#  'angoche',
#  'warqla',
#  'kavaratti',
#  'surgut',
#  'daud khel',
#  'kysyl-syr',
#  'san juan',
#  'antofagasta',
#  'ames',
#  'aksu',
#  'at-bashi',
#  'maltahohe',
#  'meadow lake',
#  'campina verde',
#  'non sung',
#  'kholm',
#  'maniitsoq',
#  'constantine',
#  'greytown',
#  'wuwei',
#  'yemtsa',
#  'arrifes',
#  'abu kamal',
#  'gorno-chuyskiy',
#  'grenada',
#  'ushtobe',
#  'dongning',
#  'stoyba',
#  'marsaxlokk',
#  'karaul',
#  'khilok',
#  'nueva loja',
#  'lufilufi',
#  'chapais',
#  'ardesen',
#  'gamboma',
#  'energetik',
#  'abu dhabi',
#  'seoul',
#  'burgeo',
#  'puerto ayacucho',
#  'beloha',
#  'hauterive',
#  'sena madureira',
#  'ayios kirikos',
#  'ishigaki',
#  'dandong',
#  'roma',
#  'sobolevo',
#  'vila do maio',
#  'palabuhanratu',
#  'sibolga',
#  'forecariah',
#  'dawson creek',
#  'chabahar',
#  'talara',
#  'rawlins',
#  'novikovo',
#  'rio verde de mato grosso']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

     # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | malibu
# Processing Record 2 of Set 1 | gazojak
# Processing Record 3 of Set 1 | necochea
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | vestmannaeyjar
# Processing Record 7 of Set 1 | tuban
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 1 | la ronge
# Processing Record 12 of Set 1 | acuna
# City not found. Skipping...
# Processing Record 13 of Set 1 | sambava
# Processing Record 14 of Set 1 | varkaus
# Processing Record 15 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | srednekolymsk
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 1 | los llanos de aridane
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | seddon
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | fontenay-le-comte
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | tura
# Processing Record 32 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | kholm-zhirkovskiy
# Processing Record 35 of Set 1 | havoysund
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | takoradi
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | kendari
# Processing Record 42 of Set 1 | andselv
# City not found. Skipping...
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | oranjemund
# Processing Record 45 of Set 1 | myrtle beach
# Processing Record 46 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 1 | soyo
# Processing Record 48 of Set 1 | port keats
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | shiraoi
# Processing Record 1 of Set 2 | jalor
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | dudinka
# Processing Record 4 of Set 2 | rabo de peixe
# Processing Record 5 of Set 2 | ust-tsilma
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | pringsewu
# Processing Record 8 of Set 2 | waipawa
# Processing Record 9 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 2 | igarka
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | kibaya
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | bairiki
# Processing Record 21 of Set 2 | san carlos de bariloche
# Processing Record 22 of Set 2 | hambantota
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | codajas
# Processing Record 29 of Set 2 | margate
# Processing Record 30 of Set 2 | zapadnaya dvina
# Processing Record 31 of Set 2 | soldatskaya
# Processing Record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | camopi
# Processing Record 35 of Set 2 | cordenons
# Processing Record 36 of Set 2 | garowe
# Processing Record 37 of Set 2 | bahua
# Processing Record 38 of Set 2 | ryotsu
# Processing Record 39 of Set 2 | sao paulo de olivenca
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | bethanien
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | coquimbo
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | mehamn
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | yarim
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | oxford
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | san isidro
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 3 | poddorye
# Processing Record 9 of Set 3 | prince albert
# Processing Record 10 of Set 3 | nemuro
# Processing Record 11 of Set 3 | benguela
# Processing Record 12 of Set 3 | borama
# City not found. Skipping...
# Processing Record 13 of Set 3 | fort nelson
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | namatanai
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | loreto
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | beira
# Processing Record 21 of Set 3 | yeppoon
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | martinsville
# Processing Record 24 of Set 3 | aswan
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | kenai
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | arman
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | ishikawa
# Processing Record 31 of Set 3 | makasar
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | stephenville
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | resistencia
# Processing Record 36 of Set 3 | funadhoo
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | preobrazheniye
# Processing Record 39 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 3 | okhotsk
# Processing Record 41 of Set 3 | qui nhon
# Processing Record 42 of Set 3 | campos novos
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 3 | abu samrah
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | san patricio
# Processing Record 48 of Set 3 | shumikha
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | kukuna
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | marystown
# Processing Record 5 of Set 4 | rodrigues alves
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | biak
# Processing Record 8 of Set 4 | bara
# Processing Record 9 of Set 4 | upernavik
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | vila velha
# Processing Record 12 of Set 4 | tigil
# Processing Record 13 of Set 4 | walvis bay
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | vila franca do campo
# Processing Record 16 of Set 4 | crossville
# Processing Record 17 of Set 4 | kahului
# Processing Record 18 of Set 4 | lodwar
# Processing Record 19 of Set 4 | kamenka
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | butaritari
# Processing Record 22 of Set 4 | moose factory
# Processing Record 23 of Set 4 | bereda
# Processing Record 24 of Set 4 | salou
# Processing Record 25 of Set 4 | umm kaddadah
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | qaqortoq
# Processing Record 28 of Set 4 | changping
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | hervey bay
# Processing Record 31 of Set 4 | ylojarvi
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | nowy dwor gdanski
# Processing Record 34 of Set 4 | kurayoshi
# Processing Record 35 of Set 4 | severo-kurilsk
# Processing Record 36 of Set 4 | riohacha
# Processing Record 37 of Set 4 | messina
# Processing Record 38 of Set 4 | lata
# Processing Record 39 of Set 4 | sitka
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | shatin
# Processing Record 42 of Set 4 | esperance
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | fenoarivo atsinanana
# Processing Record 45 of Set 4 | pechenga
# Processing Record 46 of Set 4 | tarifa
# Processing Record 47 of Set 4 | nampula
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | salta
# Processing Record 50 of Set 4 | saint-louis
# Processing Record 1 of Set 5 | huarmey
# Processing Record 2 of Set 5 | berdigestyakh
# Processing Record 3 of Set 5 | ust-kuyga
# Processing Record 4 of Set 5 | palmas bellas
# Processing Record 5 of Set 5 | kerouane
# Processing Record 6 of Set 5 | paengaroa
# Processing Record 7 of Set 5 | djambala
# Processing Record 8 of Set 5 | mhango
# Processing Record 9 of Set 5 | lagoa
# Processing Record 10 of Set 5 | laguna
# Processing Record 11 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 5 | celestun
# Processing Record 13 of Set 5 | ler
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | belogorsk
# Processing Record 19 of Set 5 | sungaipenuh
# Processing Record 20 of Set 5 | george town
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | tuy hoa
# Processing Record 23 of Set 5 | vadso
# Processing Record 24 of Set 5 | eureka
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | yebaishou
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | ratnagiri
# Processing Record 29 of Set 5 | shagonar
# Processing Record 30 of Set 5 | maceio
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | whitehorse
# Processing Record 34 of Set 5 | birao
# Processing Record 35 of Set 5 | luanda
# Processing Record 36 of Set 5 | tambo grande
# Processing Record 37 of Set 5 | hamilton
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | clyde river
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | shipley
# Processing Record 42 of Set 5 | parrita
# Processing Record 43 of Set 5 | russell
# Processing Record 44 of Set 5 | kuching
# Processing Record 45 of Set 5 | mackay
# Processing Record 46 of Set 5 | taos
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | samarai
# Processing Record 49 of Set 5 | bambanglipuro
# Processing Record 50 of Set 5 | puerto escondido
# Processing Record 1 of Set 6 | hun
# Processing Record 2 of Set 6 | evanston
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | caravelas
# Processing Record 5 of Set 6 | mayo
# Processing Record 6 of Set 6 | huilong
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | kaeo
# Processing Record 9 of Set 6 | anloga
# Processing Record 10 of Set 6 | sinnai
# Processing Record 11 of Set 6 | puerto carreno
# Processing Record 12 of Set 6 | pevek
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | luau
# Processing Record 15 of Set 6 | bullhead city
# Processing Record 16 of Set 6 | beidao
# Processing Record 17 of Set 6 | hassleholm
# Processing Record 18 of Set 6 | syracuse
# Processing Record 19 of Set 6 | mackenzie
# Processing Record 20 of Set 6 | talnakh
# Processing Record 21 of Set 6 | port macquarie
# Processing Record 22 of Set 6 | port hardy
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | penarroya-pueblonuevo
# Processing Record 25 of Set 6 | okahandja
# Processing Record 26 of Set 6 | balikpapan
# Processing Record 27 of Set 6 | dwarka
# Processing Record 28 of Set 6 | narsaq
# Processing Record 29 of Set 6 | bloomingdale
# Processing Record 30 of Set 6 | razdolinsk
# Processing Record 31 of Set 6 | denpasar
# Processing Record 32 of Set 6 | chester
# Processing Record 33 of Set 6 | davila
# Processing Record 34 of Set 6 | gondar
# Processing Record 35 of Set 6 | charters towers
# Processing Record 36 of Set 6 | ulladulla
# Processing Record 37 of Set 6 | bathsheba
# Processing Record 38 of Set 6 | lagos
# Processing Record 39 of Set 6 | ulaangom
# Processing Record 40 of Set 6 | naze
# Processing Record 41 of Set 6 | mbandaka
# Processing Record 42 of Set 6 | tomatlan
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | pemba
# Processing Record 45 of Set 6 | ballina
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | bredasdorp
# Processing Record 48 of Set 6 | blind river
# Processing Record 49 of Set 6 | kavieng
# Processing Record 50 of Set 6 | lompoc
# Processing Record 1 of Set 7 | miri
# Processing Record 2 of Set 7 | bonthe
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | belmopan
# Processing Record 5 of Set 7 | marzuq
# Processing Record 6 of Set 7 | jackson
# Processing Record 7 of Set 7 | tessalit
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | texas city
# Processing Record 10 of Set 7 | burica
# City not found. Skipping...
# Processing Record 11 of Set 7 | padang
# Processing Record 12 of Set 7 | portland
# Processing Record 13 of Set 7 | acapulco
# Processing Record 14 of Set 7 | brae
# Processing Record 15 of Set 7 | mandera
# Processing Record 16 of Set 7 | killybegs
# Processing Record 17 of Set 7 | auki
# Processing Record 18 of Set 7 | verkh-suetka
# Processing Record 19 of Set 7 | mandalgovi
# Processing Record 20 of Set 7 | damietta
# Processing Record 21 of Set 7 | saint george
# Processing Record 22 of Set 7 | mandan
# Processing Record 23 of Set 7 | tyrma
# Processing Record 24 of Set 7 | rio gallegos
# Processing Record 25 of Set 7 | mingshui
# Processing Record 26 of Set 7 | korostyshiv
# Processing Record 27 of Set 7 | warri
# Processing Record 28 of Set 7 | port blair
# Processing Record 29 of Set 7 | asau
# Processing Record 30 of Set 7 | hadejia
# Processing Record 31 of Set 7 | springbok
# Processing Record 32 of Set 7 | uyemskiy
# Processing Record 33 of Set 7 | tokur
# Processing Record 34 of Set 7 | saint anthony
# Processing Record 35 of Set 7 | kempsey
# Processing Record 36 of Set 7 | baracoa
# Processing Record 37 of Set 7 | general pico
# Processing Record 38 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 7 | lerwick
# Processing Record 40 of Set 7 | lac du bonnet
# Processing Record 41 of Set 7 | charyshskoye
# Processing Record 42 of Set 7 | bloomington
# Processing Record 43 of Set 7 | mapiripan
# Processing Record 44 of Set 7 | sao felix do xingu
# Processing Record 45 of Set 7 | zambezi
# Processing Record 46 of Set 7 | muskegon
# Processing Record 47 of Set 7 | oistins
# Processing Record 48 of Set 7 | nioro
# Processing Record 49 of Set 7 | afanasyevo
# City not found. Skipping...
# Processing Record 50 of Set 7 | norman wells
# Processing Record 1 of Set 8 | rocha
# Processing Record 2 of Set 8 | yongan
# Processing Record 3 of Set 8 | cambridge
# Processing Record 4 of Set 8 | qixia
# Processing Record 5 of Set 8 | harper
# Processing Record 6 of Set 8 | bilma
# Processing Record 7 of Set 8 | altay
# Processing Record 8 of Set 8 | zempoala
# Processing Record 9 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 8 | batemans bay
# Processing Record 11 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 8 | cayenne
# Processing Record 13 of Set 8 | vokhma
# Processing Record 14 of Set 8 | elverum
# Processing Record 15 of Set 8 | sorong
# Processing Record 16 of Set 8 | touros
# Processing Record 17 of Set 8 | gbarnga
# Processing Record 18 of Set 8 | francisco sa
# Processing Record 19 of Set 8 | dunedin
# Processing Record 20 of Set 8 | nyimba
# Processing Record 21 of Set 8 | benjamin aceval
# Processing Record 22 of Set 8 | bari
# Processing Record 23 of Set 8 | mogadishu
# Processing Record 24 of Set 8 | zhigansk
# Processing Record 25 of Set 8 | jalu
# Processing Record 26 of Set 8 | marsh harbour
# Processing Record 27 of Set 8 | taoudenni
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | talcahuano
# Processing Record 30 of Set 8 | kismayo
# Processing Record 31 of Set 8 | mokhsogollokh
# Processing Record 32 of Set 8 | cuxhaven
# Processing Record 33 of Set 8 | kirakira
# Processing Record 34 of Set 8 | burla
# Processing Record 35 of Set 8 | cap-aux-meules
# Processing Record 36 of Set 8 | te anau
# Processing Record 37 of Set 8 | zaozerne
# Processing Record 38 of Set 8 | marsa matruh
# Processing Record 39 of Set 8 | ialibu
# Processing Record 40 of Set 8 | vondrozo
# Processing Record 41 of Set 8 | saurimo
# Processing Record 42 of Set 8 | nelson bay
# Processing Record 43 of Set 8 | ambagarh chauki
# Processing Record 44 of Set 8 | katobu
# Processing Record 45 of Set 8 | indian head
# Processing Record 46 of Set 8 | ahipara
# Processing Record 47 of Set 8 | eregli
# Processing Record 48 of Set 8 | sindor
# Processing Record 49 of Set 8 | zhengjiatun
# Processing Record 50 of Set 8 | maloy
# Processing Record 1 of Set 9 | thinadhoo
# Processing Record 2 of Set 9 | male
# Processing Record 3 of Set 9 | saint-pierre
# Processing Record 4 of Set 9 | kuusamo
# Processing Record 5 of Set 9 | moshny
# Processing Record 6 of Set 9 | port hedland
# Processing Record 7 of Set 9 | ancud
# Processing Record 8 of Set 9 | villa carlos paz
# Processing Record 9 of Set 9 | santa isabel do rio negro
# Processing Record 10 of Set 9 | novo aripuana
# Processing Record 11 of Set 9 | the valley
# Processing Record 12 of Set 9 | gat
# Processing Record 13 of Set 9 | bandarbeyla
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | sabang
# Processing Record 16 of Set 9 | semme
# Processing Record 17 of Set 9 | troitsko-pechorsk
# Processing Record 18 of Set 9 | tanout
# Processing Record 19 of Set 9 | tamiahua
# Processing Record 20 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 9 | tibu
# Processing Record 22 of Set 9 | fare
# Processing Record 23 of Set 9 | lagunas
# Processing Record 24 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 9 | tarauaca
# Processing Record 26 of Set 9 | mount isa
# Processing Record 27 of Set 9 | puerto baquerizo moreno
# Processing Record 28 of Set 9 | khasan
# Processing Record 29 of Set 9 | belize
# Processing Record 30 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 9 | longyearbyen
# Processing Record 32 of Set 9 | teya
# Processing Record 33 of Set 9 | sovetskaya gavan
# Processing Record 34 of Set 9 | poum
# Processing Record 35 of Set 9 | san jose
# Processing Record 36 of Set 9 | lucapa
# Processing Record 37 of Set 9 | sao joao da barra
# Processing Record 38 of Set 9 | susanville
# Processing Record 39 of Set 9 | havelock
# Processing Record 40 of Set 9 | belyy yar
# Processing Record 41 of Set 9 | yulara
# Processing Record 42 of Set 9 | powell river
# Processing Record 43 of Set 9 | baherden
# Processing Record 44 of Set 9 | grindavik
# Processing Record 45 of Set 9 | binga
# Processing Record 46 of Set 9 | alenquer
# Processing Record 47 of Set 9 | yantal
# Processing Record 48 of Set 9 | anadyr
# Processing Record 49 of Set 9 | araouane
# Processing Record 50 of Set 9 | oriximina
# Processing Record 1 of Set 10 | bubaque
# Processing Record 2 of Set 10 | larsnes
# Processing Record 3 of Set 10 | montepuez
# Processing Record 4 of Set 10 | bafoulabe
# Processing Record 5 of Set 10 | lugovoy
# Processing Record 6 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | deder
# Processing Record 8 of Set 10 | ginebra
# Processing Record 9 of Set 10 | pemangkat
# Processing Record 10 of Set 10 | bayangol
# Processing Record 11 of Set 10 | praya
# Processing Record 12 of Set 10 | tunxi
# City not found. Skipping...
# Processing Record 13 of Set 10 | nikki
# Processing Record 14 of Set 10 | ambunti
# Processing Record 15 of Set 10 | port lincoln
# Processing Record 16 of Set 10 | aklavik
# Processing Record 17 of Set 10 | saint-joseph
# Processing Record 18 of Set 10 | seaforth
# Processing Record 19 of Set 10 | pinega
# Processing Record 20 of Set 10 | paamiut
# Processing Record 21 of Set 10 | andenes
# Processing Record 22 of Set 10 | aosta
# Processing Record 23 of Set 10 | stokmarknes
# Processing Record 24 of Set 10 | ouahigouya
# Processing Record 25 of Set 10 | gabi
# Processing Record 26 of Set 10 | kristiinankaupunki
# Processing Record 27 of Set 10 | havre-saint-pierre
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | moshi
# Processing Record 30 of Set 10 | praia da vitoria
# Processing Record 31 of Set 10 | nynashamn
# Processing Record 32 of Set 10 | leningradskiy
# Processing Record 33 of Set 10 | sinnamary
# Processing Record 34 of Set 10 | tambun
# Processing Record 35 of Set 10 | udachnyy
# Processing Record 36 of Set 10 | povolzhskiy
# Processing Record 37 of Set 10 | henties bay
# Processing Record 38 of Set 10 | behshahr
# Processing Record 39 of Set 10 | de-kastri
# Processing Record 40 of Set 10 | gizo
# Processing Record 41 of Set 10 | half moon bay
# Processing Record 42 of Set 10 | broken hill
# Processing Record 43 of Set 10 | riacho de santana
# Processing Record 44 of Set 10 | verkhoyansk
# Processing Record 45 of Set 10 | grand gaube
# Processing Record 46 of Set 10 | panzhihua
# Processing Record 47 of Set 10 | baie-comeau
# Processing Record 48 of Set 10 | lewisporte
# Processing Record 49 of Set 10 | meridian
# Processing Record 50 of Set 10 | avera
# Processing Record 1 of Set 11 | dikson
# Processing Record 2 of Set 11 | pacific grove
# Processing Record 3 of Set 11 | trinec
# Processing Record 4 of Set 11 | fallon
# Processing Record 5 of Set 11 | inta
# Processing Record 6 of Set 11 | cockburn town
# Processing Record 7 of Set 11 | waitati
# Processing Record 8 of Set 11 | el alto
# Processing Record 9 of Set 11 | scalea
# Processing Record 10 of Set 11 | waterloo
# Processing Record 11 of Set 11 | brive-la-gaillarde
# Processing Record 12 of Set 11 | nuevo progreso
# Processing Record 13 of Set 11 | ranau
# Processing Record 14 of Set 11 | constitucion
# Processing Record 15 of Set 11 | sao filipe
# Processing Record 16 of Set 11 | muros
# Processing Record 17 of Set 11 | buala
# Processing Record 18 of Set 11 | inirida
# Processing Record 19 of Set 11 | pasighat
# Processing Record 20 of Set 11 | nishihara
# Processing Record 21 of Set 11 | nantucket
# Processing Record 22 of Set 11 | clonakilty
# Processing Record 23 of Set 11 | kuito
# Processing Record 24 of Set 11 | san andres
# Processing Record 25 of Set 11 | sakakah
# Processing Record 26 of Set 11 | el cobre
# Processing Record 27 of Set 11 | kuressaare
# Processing Record 28 of Set 11 | caluquembe
# Processing Record 29 of Set 11 | altar
# Processing Record 30 of Set 11 | pangai
# Processing Record 31 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 11 | belmonte
# Processing Record 33 of Set 11 | moron
# Processing Record 34 of Set 11 | korgen
# Processing Record 35 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 36 of Set 11 | carutapera
# Processing Record 37 of Set 11 | montrose
# Processing Record 38 of Set 11 | quimper
# Processing Record 39 of Set 11 | xichang
# Processing Record 40 of Set 11 | sinazongwe
# Processing Record 41 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 11 | kodinsk
# Processing Record 43 of Set 11 | aksarka
# Processing Record 44 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 11 | ucluelet
# Processing Record 46 of Set 11 | san jose de tarros
# Processing Record 47 of Set 11 | high level
# Processing Record 48 of Set 11 | haines junction
# Processing Record 49 of Set 11 | bo phloi
# Processing Record 50 of Set 11 | mabaruma
# Processing Record 1 of Set 12 | kresttsy
# Processing Record 2 of Set 12 | lundazi
# Processing Record 3 of Set 12 | mizdah
# Processing Record 4 of Set 12 | beinamar
# Processing Record 5 of Set 12 | salinopolis
# Processing Record 6 of Set 12 | namibe
# Processing Record 7 of Set 12 | faya
# Processing Record 8 of Set 12 | eyl
# Processing Record 9 of Set 12 | castanos
# Processing Record 10 of Set 12 | oliver
# Processing Record 11 of Set 12 | san policarpo
# Processing Record 12 of Set 12 | san jeronimo
# Processing Record 13 of Set 12 | tequila
# Processing Record 14 of Set 12 | ranong
# Processing Record 15 of Set 12 | fortuna
# Processing Record 16 of Set 12 | eenhana
# Processing Record 17 of Set 12 | birjand
# Processing Record 18 of Set 12 | vila
# Processing Record 19 of Set 12 | ust-maya
# Processing Record 20 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 21 of Set 12 | nizhneivkino
# Processing Record 22 of Set 12 | talas
# Processing Record 23 of Set 12 | darnah
# Processing Record 24 of Set 12 | alta floresta
# Processing Record 25 of Set 12 | dalianwan
# Processing Record 26 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 27 of Set 12 | tuatapere
# Processing Record 28 of Set 12 | hirado
# Processing Record 29 of Set 12 | sola
# Processing Record 30 of Set 12 | tayshet
# Processing Record 31 of Set 12 | zemio
# Processing Record 32 of Set 12 | banugao
# Processing Record 33 of Set 12 | verkhnevilyuysk
# Processing Record 34 of Set 12 | buraydah
# Processing Record 35 of Set 12 | soubre
# Processing Record 36 of Set 12 | mangochi
# Processing Record 37 of Set 12 | bud
# Processing Record 38 of Set 12 | deer lake
# Processing Record 39 of Set 12 | avdiyivka
# Processing Record 40 of Set 12 | kamyshin
# Processing Record 41 of Set 12 | ayr
# Processing Record 42 of Set 12 | opuwo
# Processing Record 43 of Set 12 | kytlym
# City not found. Skipping...
# Processing Record 44 of Set 12 | airai
# Processing Record 45 of Set 12 | gaffney
# Processing Record 46 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 12 | comodoro rivadavia
# Processing Record 48 of Set 12 | wakkanai
# Processing Record 49 of Set 12 | goundam
# Processing Record 50 of Set 12 | arlit
# Processing Record 1 of Set 13 | estelle
# Processing Record 2 of Set 13 | katherine
# Processing Record 3 of Set 13 | iowa city
# Processing Record 4 of Set 13 | la palma
# Processing Record 5 of Set 13 | hasaki
# Processing Record 6 of Set 13 | khani
# Processing Record 7 of Set 13 | waingapu
# Processing Record 8 of Set 13 | malitbog
# Processing Record 9 of Set 13 | akcakoca
# Processing Record 10 of Set 13 | northam
# Processing Record 11 of Set 13 | husavik
# Processing Record 12 of Set 13 | cessnock
# Processing Record 13 of Set 13 | bogatic
# Processing Record 14 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 15 of Set 13 | usinsk
# Processing Record 16 of Set 13 | turukhansk
# Processing Record 17 of Set 13 | cloquet
# Processing Record 18 of Set 13 | port-gentil
# Processing Record 19 of Set 13 | dunkirk
# Processing Record 20 of Set 13 | prado
# Processing Record 21 of Set 13 | vostok
# Processing Record 22 of Set 13 | siavonga
# Processing Record 23 of Set 13 | maridi
# Processing Record 24 of Set 13 | babu
# Processing Record 25 of Set 13 | wanning
# Processing Record 26 of Set 13 | contai
# Processing Record 27 of Set 13 | sioux lookout
# Processing Record 28 of Set 13 | nome
# Processing Record 29 of Set 13 | teknaf
# Processing Record 30 of Set 13 | sept-iles
# Processing Record 31 of Set 13 | dubbo
# Processing Record 32 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 33 of Set 13 | mount pleasant
# Processing Record 34 of Set 13 | gravdal
# Processing Record 35 of Set 13 | batalha
# Processing Record 36 of Set 13 | millinocket
# Processing Record 37 of Set 13 | hokitika
# Processing Record 38 of Set 13 | jaicos
# Processing Record 39 of Set 13 | amahai
# Processing Record 40 of Set 13 | isla aguada
# Processing Record 41 of Set 13 | vung tau
# Processing Record 42 of Set 13 | maracas
# Processing Record 43 of Set 13 | lensk
# Processing Record 44 of Set 13 | ketchikan
# Processing Record 45 of Set 13 | praia
# Processing Record 46 of Set 13 | honiara
# Processing Record 47 of Set 13 | tabuk
# Processing Record 48 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 49 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 13 | mangrol
# Processing Record 1 of Set 14 | ndjole
# Processing Record 2 of Set 14 | balkhash
# Processing Record 3 of Set 14 | kutum
# Processing Record 4 of Set 14 | dingli
# Processing Record 5 of Set 14 | solnechnyy
# Processing Record 6 of Set 14 | vestmanna
# Processing Record 7 of Set 14 | hearst
# Processing Record 8 of Set 14 | kachug
# Processing Record 9 of Set 14 | sohagpur
# Processing Record 10 of Set 14 | chernyshevskiy
# Processing Record 11 of Set 14 | byron bay
# Processing Record 12 of Set 14 | omurtag
# Processing Record 13 of Set 14 | nara
# Processing Record 14 of Set 14 | qasigiannguit
# Processing Record 15 of Set 14 | jieshi
# Processing Record 16 of Set 14 | ostrovnoy
# Processing Record 17 of Set 14 | chicama
# Processing Record 18 of Set 14 | longview
# Processing Record 19 of Set 14 | aras
# Processing Record 20 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 14 | ashland
# Processing Record 22 of Set 14 | bowmore
# Processing Record 23 of Set 14 | santa vitoria do palmar
# Processing Record 24 of Set 14 | boguchany
# Processing Record 25 of Set 14 | rosehearty
# Processing Record 26 of Set 14 | kupang
# Processing Record 27 of Set 14 | san quintin
# Processing Record 28 of Set 14 | cabo san lucas
# Processing Record 29 of Set 14 | kulhudhuffushi
# Processing Record 30 of Set 14 | assiniboia
# Processing Record 31 of Set 14 | belur
# Processing Record 32 of Set 14 | kisangani
# Processing Record 33 of Set 14 | nizhniy odes
# Processing Record 34 of Set 14 | waw
# Processing Record 35 of Set 14 | leiva
# Processing Record 36 of Set 14 | nizwa
# Processing Record 37 of Set 14 | sarkand
# Processing Record 38 of Set 14 | filingue
# Processing Record 39 of Set 14 | san cristobal
# Processing Record 40 of Set 14 | bemidji
# Processing Record 41 of Set 14 | osmena
# Processing Record 42 of Set 14 | labuhan
# Processing Record 43 of Set 14 | saint-francois
# Processing Record 44 of Set 14 | alice springs
# Processing Record 45 of Set 14 | matara
# Processing Record 46 of Set 14 | koundara
# Processing Record 47 of Set 14 | olafsvik
# Processing Record 48 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 14 | tulum
# Processing Record 50 of Set 14 | sahuaripa
# Processing Record 1 of Set 15 | mount gambier
# Processing Record 2 of Set 15 | mkushi
# Processing Record 3 of Set 15 | george
# Processing Record 4 of Set 15 | kijang
# Processing Record 5 of Set 15 | pechora
# Processing Record 6 of Set 15 | bilibino
# Processing Record 7 of Set 15 | dryden
# Processing Record 8 of Set 15 | puerto madryn
# Processing Record 9 of Set 15 | panaba
# Processing Record 10 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 11 of Set 15 | tabursuq
# Processing Record 12 of Set 15 | bhatgaon
# Processing Record 13 of Set 15 | naliya
# Processing Record 14 of Set 15 | artsyz
# Processing Record 15 of Set 15 | magalia
# Processing Record 16 of Set 15 | angoche
# Processing Record 17 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 15 | kavaratti
# Processing Record 19 of Set 15 | surgut
# Processing Record 20 of Set 15 | daud khel
# Processing Record 21 of Set 15 | kysyl-syr
# Processing Record 22 of Set 15 | san juan
# Processing Record 23 of Set 15 | antofagasta
# Processing Record 24 of Set 15 | ames
# Processing Record 25 of Set 15 | aksu
# Processing Record 26 of Set 15 | at-bashi
# Processing Record 27 of Set 15 | maltahohe
# Processing Record 28 of Set 15 | meadow lake
# Processing Record 29 of Set 15 | campina verde
# Processing Record 30 of Set 15 | non sung
# Processing Record 31 of Set 15 | kholm
# Processing Record 32 of Set 15 | maniitsoq
# Processing Record 33 of Set 15 | constantine
# Processing Record 34 of Set 15 | greytown
# Processing Record 35 of Set 15 | wuwei
# Processing Record 36 of Set 15 | yemtsa
# Processing Record 37 of Set 15 | arrifes
# Processing Record 38 of Set 15 | abu kamal
# Processing Record 39 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | grenada
# Processing Record 41 of Set 15 | ushtobe
# Processing Record 42 of Set 15 | dongning
# Processing Record 43 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 44 of Set 15 | marsaxlokk
# Processing Record 45 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 15 | khilok
# Processing Record 47 of Set 15 | nueva loja
# Processing Record 48 of Set 15 | lufilufi
# Processing Record 49 of Set 15 | chapais
# Processing Record 50 of Set 15 | ardesen
# Processing Record 1 of Set 16 | gamboma
# Processing Record 2 of Set 16 | energetik
# Processing Record 3 of Set 16 | abu dhabi
# Processing Record 4 of Set 16 | seoul
# Processing Record 5 of Set 16 | burgeo
# Processing Record 6 of Set 16 | puerto ayacucho
# Processing Record 7 of Set 16 | beloha
# Processing Record 8 of Set 16 | hauterive
# Processing Record 9 of Set 16 | sena madureira
# Processing Record 10 of Set 16 | ayios kirikos
# City not found. Skipping...
# Processing Record 11 of Set 16 | ishigaki
# Processing Record 12 of Set 16 | dandong
# Processing Record 13 of Set 16 | roma
# Processing Record 14 of Set 16 | sobolevo
# Processing Record 15 of Set 16 | vila do maio
# Processing Record 16 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 16 | sibolga
# Processing Record 18 of Set 16 | forecariah
# Processing Record 19 of Set 16 | dawson creek
# Processing Record 20 of Set 16 | chabahar
# Processing Record 21 of Set 16 | talara
# Processing Record 22 of Set 16 | rawlins
# Processing Record 23 of Set 16 | novikovo
# Processing Record 24 of Set 16 | rio verde de mato grosso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 716

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Malibu  34.0050 -118.8101     72.10        87          20
# 1         Gazojak  41.1875   61.4036     60.84        42          70
# 2        Necochea -38.5473  -58.7368     47.97        79          20
# 3            Hami  42.8000   93.4500     54.70        22           4
# 4  Port Elizabeth -33.9180   25.5701     67.10        96         100
# 5  Vestmannaeyjar  63.4427  -20.2734     41.49        65           4
# 6           Tuban  -6.8976  112.0649     82.60        71         100
# 7         Ushuaia -54.8000  -68.3000     44.26        61           0
# 8        Hermanus -34.4187   19.2345     58.80        88           0
# 9        La Ronge  55.1001 -105.2842     35.85        55         100
#
#    Wind Speed Country                 Date      Description
# 0        1.99      US  2022-10-17 01:25:56       few clouds
# 1       11.16      TM  2022-10-17 01:27:43    broken clouds
# 2       10.27      AR  2022-10-17 01:27:43       few clouds
# 3        0.96      CN  2022-10-17 01:27:43        clear sky
# 4        3.44      ZA  2022-10-17 01:25:39  overcast clouds
# 5        4.34      IS  2022-10-17 01:24:46        clear sky
# 6       14.72      ID  2022-10-17 01:23:29  overcast clouds
# 7        1.14      AR  2022-10-17 01:25:44        clear sky
# 8        6.85      ZA  2022-10-17 01:21:19        clear sky
# 9        9.22      CA  2022-10-17 01:27:44  overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new]

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Malibu      US  34.0050 -118.8101     72.10        87          20
# 1         Gazojak      TM  41.1875   61.4036     60.84        42          70
# 2        Necochea      AR -38.5473  -58.7368     47.97        79          20
# 3            Hami      CN  42.8000   93.4500     54.70        22           4
# 4  Port Elizabeth      ZA -33.9180   25.5701     67.10        96         100
#
#    Wind Speed      Description
# 0        1.99       few clouds
# 1       11.16    broken clouds
# 2       10.27       few clouds
# 3        0.96        clear sky
# 4        3.44  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
